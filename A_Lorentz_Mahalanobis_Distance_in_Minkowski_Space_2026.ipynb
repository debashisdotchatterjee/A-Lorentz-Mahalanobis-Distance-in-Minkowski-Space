# %% [markdown]
# <a href="https://colab.research.google.com/github/debashisdotchatterjee/A-Lorentz-Mahalanobis-Distance-in-Minkowski-Space/blob/main/A_Lorentz_Mahalanobis_Distance_in_Minkowski_Space_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Simulation: Small Test Run**

# %% [markdown]
# I made a clean downloadable package containing:
#
# LM_Advanced_Simulation_Colab.ipynb — open directly in Colab.
# lm_advanced_simulation_colab.py — plain Python script.
# README.txt — exact run instructions. Get it from Github and upload in Python and run the following

# %%
results = run_all_simulations(quick=True, make_zip=True)
# Out:
# Checking Lorentz boost matrices...
# All boost matrices preserve G up to numerical tolerance.
#
# Experiment 0: numerical equivariance diagnostic...
# Saved: lm_advanced_simulation_outputs/tables/table00_equivariance_diagnostic.csv
# Saved: lm_advanced_simulation_outputs/tables/table00_equivariance_diagnostic.tex
#
# ...
# Table 0: Score equivariance diagnostic
# ...
#     eta              method  max_abs_score_change  mean_abs_score_change  \
# 0   0.0                  LM          0.000000e+00           0.000000e+00
# 1   0.0    Euclidean oracle          0.000000e+00           0.000000e+00
# 2   0.0     Euclidean naive          0.000000e+00           0.000000e+00
# 3   0.0  Minkowski interval          0.000000e+00           0.000000e+00
# 4   0.4                  LM          1.065814e-14           3.737890e-16
# 5   0.4    Euclidean oracle          3.552714e-15           2.890882e-16
# 6   0.4     Euclidean naive          1.497488e+01           1.254075e+00
# ...

# %% [markdown]
# After confirming it (the above) works, run the final version with:

# %%
results = run_all_simulations(quick=False, make_zip=True)
# Out:
# Checking Lorentz boost matrices...
# All boost matrices preserve G up to numerical tolerance.
#
# Experiment 0: numerical equivariance diagnostic...
# Saved: lm_advanced_simulation_outputs/tables/table00_equivariance_diagnostic.csv
# Saved: lm_advanced_simulation_outputs/tables/table00_equivariance_diagnostic.tex
#
# ...
# Table 0: Score equivariance diagnostic
# ...
#     eta              method  max_abs_score_change  mean_abs_score_change  \
# 0   0.0                  LM          0.000000e+00           0.000000e+00
# 1   0.0    Euclidean oracle          0.000000e+00           0.000000e+00
# 2   0.0     Euclidean naive          0.000000e+00           0.000000e+00
# 3   0.0  Minkowski interval          0.000000e+00           0.000000e+00
# 4   0.4                  LM          7.105427e-15           3.659807e-16
# 5   0.4    Euclidean oracle          7.105427e-15           2.727540e-16
# 6   0.4     Euclidean naive          1.813806e+01           1.263264e+00
# ...
