# %% [markdown]
# # Clean real-data Lorentz--Mahalanobis analysis
#
# Run the cells below in order. This clean version omits non-informative outputs from the earlier workflow.

# %%
# !pip -q install energyflow scikit-learn h5py tables tqdm

# %%
from pathlib import Path
import zipfile, sys, os

# Extract package if uploaded as ZIP
for z in Path('/content').glob('lm_realdata_clean_methodology_package*.zip'):
    print('Extracting:', z)
    with zipfile.ZipFile(z, 'r') as zf:
        zf.extractall('/content')

candidates = [
    Path('/content/lm_realdata_clean_methodology_package'),
    Path.cwd(),
]
pkg_dir = None
for d in candidates:
    if (d / 'lm_realdata_analysis_clean.py').exists():
        pkg_dir = d
        break

if pkg_dir is None:
    raise FileNotFoundError('Could not find lm_realdata_analysis_clean.py. Please extract/upload the package.')

sys.path.insert(0, str(pkg_dir))
os.chdir(str(pkg_dir))
print('Using package directory:', pkg_dir)

# %%
from lm_realdata_analysis_clean import CLEAN_CONFIG, run_clean_realdata_analysis
print('Imported clean runner successfully.')

# %% [markdown]
# For a quick debugging run, uncomment the smaller settings in the next cell. For final output, keep the defaults.

# %%
# Optional debugging settings:
# CLEAN_CONFIG['max_jets_analysis'] = 20000
# CLEAN_CONFIG['permutation_B'] = 199

results = run_clean_realdata_analysis(CLEAN_CONFIG, make_zip=True)
